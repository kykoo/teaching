# %% [markdown]
# ---
# format:
#   html:
#     output-file: index.html
#     number-sections: false
# ---

# %% [markdown]
# ## Teaching
#
# - [2026-03-01-civil-engineering-why](https://kykoo.github.io/teaching/2026-03-01-civil-engineering-why/civil-eng-programme.html)
